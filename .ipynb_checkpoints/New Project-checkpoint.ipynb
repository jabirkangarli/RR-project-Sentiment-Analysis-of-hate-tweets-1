# %% [markdown]
# # Sentiment analysis of the spread of hate in tweets using RNN

# %% [markdown]
# ## 1. Understanding the Problem Statement

# %% [markdown]
# Twitter is one of the biggest and most popular social networks with around 300 million users, 40% of which are active on the platform multiple times per day. Hence, it’s understandable the need to monitor the sentiment of the users, especially if it can help stop the spread of hateful and damaging massages.
#
# The goal of our project is to reproduce the original project and to replicate the results using the dataset described below, with the aim of building a robust model for predicting hate tweets. The model is based on Recurrent Neural Networks (RNNs), with the implementation and evaluation of different layers such as LSTM, GRU. Furthermore, we used pretrained word vectors from GloVe model trained with tweets, which is loaded in our model in an Embedding layer.

# %% [markdown]
# ## 2. About the dataset

# %% [markdown]
# The data used was found on Kaggle:
#
# https://www.kaggle.com/datasets/ashwiniyer176/toxic-tweets-dataset
#
# The dataset used to build and evaluate the model contains 56,744 rows and three columns:
#
#     id - ID assigned to each tweet
#     label - 1 if the tweeter is considered hateful and 0 non-hateful
#     tweet - string containing tweet’s text.

# %% [markdown]
# ## 3. Import Libraries

# %%
# Import modules

import numpy
import numpy as np
from numpy.random import seed

import pandas as pd
import matplotlib.pyplot as plt
import re
import spacy
import inspect
import tensorflow
from wordcloud import WordCloud, STOPWORDS
from nltk import FreqDist

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dropout
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.utils.np_utils import to_categorical
from keras.initializers import Constant

# %% [markdown]
# ## 4. Read and Inspect the Data

# %%
data_columns = ["ids","label","tweet"]
tweets= pd.read_csv('training.csv', names=data_columns)[1:]
tweets.head()
# Out:
#    ids label                                              tweet
# 1  0.0     0   @user when a father is dysfunctional and is s...
# 2  1.0     0  @user @user thanks for #lyft credit i can't us...
# 3  2.0     0                                bihday your majesty
# 4  3.0     0  #model   i love u take with u all the time in ...
# 5  4.0     0             factsguide: society now    #motivation

# %%
tweets["label"].replace({"0": 0, "1": 1}, inplace=True)

# %%
np.unique(tweets.label)
# Out:
# array([0, 1])

# %%
print("Hatred labeled: {}\nNon-hatred labeled: {}".format(
    (tweets.label == 1).sum(),
    (tweets.label == 0).sum()
))
# Out:
# Hatred labeled: 24153
# Non-hatred labeled: 32592

# %% [markdown]
# ## 5. Text Cleaning and Preprocessing

# %%
# remove URL's and @users
tweets['clean_tweet'] = tweets['tweet'].apply(lambda x: re.sub(r'http\S+', '', x))
tweets['clean_tweet'] = tweets['clean_tweet'].apply(lambda x: re.sub(r'&#\S+', '', x))
tweets['clean_tweet'] = tweets['clean_tweet'].apply(lambda x: re.sub('@[a-zA-Z0-9_]+', '', x))

# %%
#Removing hashtags and creating hashtags column
hashtags = tweets['clean_tweet'].str.extractall('#(?P<hashtag>[a-zA-Z0-9_]+)').reset_index().groupby('level_0').agg(lambda x: ' '.join(x.values))
tweets.loc[:, 'hashtags'] = hashtags['hashtag']
tweets['hashtags'].fillna('', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py:303: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results[key] = self.aggregate(func)

# %%
# remove punctuation marks
punctuation = '!"#$%&()*+-/:;<=>?@[\\]^_`{|}~'

tweets['clean_tweet'] = tweets['clean_tweet'].apply(lambda x: ''.join(ch for ch in x if ch not in set(punctuation)))

# convert text to lowercase
tweets['clean_tweet'] = tweets['clean_tweet'].str.lower()

# remove numbers
tweets['clean_tweet'] = tweets['clean_tweet'].str.replace("[0-9]", " ")

# remove whitespaces
tweets['clean_tweet'] = tweets['clean_tweet'].apply(lambda x:' '.join(x.split()))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Lemmatizing tweets

#!pip3 install -U spacy
#!python3 -m spacy download en_core_web_sm

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# function to lemmatize text
def lemmatization(texts):
    output = []
    for i in texts:
        s = [token.lemma_ for token in nlp(i)]
        output.append(' '.join(s))
    return output

# %%
tweets['clean_tweet'] = lemmatization(tweets['clean_tweet'])

# %%
#Removing whatever non-character rest that could remain in the tweets

tweets['clean_tweet2'] = tweets.clean_tweet.str.replace('[^a-zA-Z]', ' ')
#tweets['lwords'] = tweets['clean_tweet2'].apply(lambda x: x.split())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
tweets.sample(50)
# Out:
#            ids  label                                              tweet  \
# 3020    3019.0      1  #texas the principal resigned!  #justicereform...
# 30901  30900.0      1  @user #allahsoil culture is like the horizonâ...
# 46268  46267.0      1  RT @BandWorld1 That bitch who the shit in yo e...
# 52328  52327.0      1  RT @xM_3Times: Yung nation- riot . Still bump ...
# 9255    9254.0      0       @user hi @user my friend   #lokiday for you
# 40462  40461.0      1                            Coke and white bitches.
# 22604  22603.0      0  #my bihday friday. princess eden deserves #gif...
# 17171  17170.0      0  i am thankful for happiness. #thankful #positi...
# 17869  17868.0      0  cheers! it's #friday ya'll! happy hours are al...
# 12416  12415.0      0  i am thankful for clothes. #thankful #positive...
# 40305  40304.0      1      Can't fuck with no bitches. Just can't do it.
# 45417  45416.0      0  Not that I plan on dying soon, but I'm totally...
# 43457  43456.0      1  If I don't unwrap a big booty hoe today i'm go...
# 53964  53963.0      1  This bitch said "Use my titties as a punchin b...
# 842      841.0      0        .@user a number of our leaders are coming
# 362      361.0      0  best #lawofattraction #resources for #healing!...
# 5317    5316.0      0       threats from terrorists are becoming real
# 35190  35189.0      1            @GOOSEmon420er you were there bitch lol
# 21317  21316.0      0   @user and yet the dems have no issue with abo...
# 56142  56141.0      1  lol RT @_mykall: when you @ bae game &amp; an ...
# 23618  23617.0      0  red lips x navy top #girl #me #selfie #redlips...
# 51498  51497.0      0  RT @lildurk_: S/o all my real fans who can wai...
# 1810    1809.0      0  the simple things in life make one happy #smil...
# 36367  36366.0      1  @Pepper_Redbone @Yankees @Mets Oh yeah. And th...
# 5474    5473.0      0            figgity figgity fucked up #emo   #yikez
# 46882  46881.0      1  RT @DamonIWantYou: #TVD and #Theoriginals is t...
# 33226  33225.0      1  &#8220;@FunnyPicsDepot: When the nigga with th...
# 38696  38695.0      1  @mrrickyguevara lmao why would we respect him ...
# 17044  17043.0      0  i listened to @user podcast and realized the @...
# 54392  54391.0      1                                            W bitch
# 51460  51459.0      1  RT @lavishlolaaaaaa: Bitches be out here eatin...
# 40465  40464.0      1  Come back hoe @kati_dupree843 http://t.co/1UPx...
# 53493  53492.0      1  The bitch who just rolled her eyes at me bc sh...
# 10021  10020.0      0  racist assholes! ban one of the sweetest and k...
# 29971  29970.0      1  @user @user the kind of  we can expect in #tru...
# 42005  42004.0      0  I be jamming Skid Row,Kix,Cinderella,Damn Yank...
# 24397  24396.0      0  bloody love my manager @user look at him the h...
# 9083    9082.0      0         just gonna lay in my bed and cry all day
# 51686  51685.0      0  RT @musedbymusic: Thanks to @TonyJRodriguez I ...
# 28152  28151.0      1  @user donald  - putin's butt buddy and a commie.
# 4630    4629.0      0  i'll never forget you. #asian #teen #gay #boy ...
# 56727  56726.0      1  you gotta understand that these bitches are ch...
# 21568  21567.0      0  looking forward to our âmasterchef designed ...
# 4787    4786.0      0  ...friday ð wine ð· chill!!! #thankgod   ...
# 43113  43112.0      1  I'd hit a Kardashian she threw money at me bru...
# 14831  14830.0      0  every time i hear the ice cream truck, i'm jus...
# 26068  26067.0      0  i'm so thankful that @user introduced me to he...
# 39537  39536.0      0  All I wants is to represent da life o da color...
# 15688  15687.0      0  well, it blew up 2 laps into the feature. toug...
# 49129  49128.0      1    RT @SLeyTMF: Too many bitches not enough queens
#
#                                              clean_tweet  \
# 3020   texas the principal resign justicereform the p...
# 30901  allahsoil culture be like the horizonâalways...
# 46268  rt that bitch who the shit in yo eye be not sh...
# 52328          rt yung nation riot . still bump that hoe
# 9255                 hi -PRON- friend lokiday for -PRON-
# 40462                             coke and white bitch .
# 22604  -PRON- bihday friday . princess eden deserve g...
# 17171    i be thankful for happiness . thankful positive
# 17869  cheer -PRON- be friday ya'll happy hour be alw...
# 12416       i be thankful for clothe . thankful positive
# 40305  can not fuck with no bitch . just can not do -...
# 45417  not that i plan on die soon , but -PRON- be to...
# 43457  if i do not unwrap a big booty hoe today -PRON...
# 53964  this bitch say use -PRON- titty as a punchin b...
# 842                  . a number of -PRON- leader be come
# 362    good lawofattraction resource for heal altways...
# 5317                threat from terrorist be become real
# 35190                          -PRON- be there bitch lol
# 21317  and yet the dem have no issue with aboion , cl...
# 56142  lol rt when -PRON- bae game amp an unknown hoe...
# 23618  red lips x navy top girl -PRON- selfie redlip ...
# 51498  rt so all -PRON- real fan who can wait and not...
# 1810   the simple thing in life make one happy smile ...
# 36367  oh yeah . and the annoying damn duck call -PRO...
# 5474                   figgity figgity fuck up emo yikez
# 46882  rt tvd and theoriginal be the show bad ass vam...
# 33226  when the nigga with the aux cord playin some t...
# 38696  lmao why would -PRON- respect -PRON- then -PRO...
# 17044  i listen to podcast and realize the should be ...
# 54392                                            w bitch
# 51460  rt bitches be out here eat pussy more than niggas
# 40465                                      come back hoe
# 53493  the bitch who just roll -PRON- eye at -PRON- b...
# 10021  racist assholes ban one of the sweetest and ki...
# 29971      the kind of -PRON- can expect in trump amrica
# 42005  i be jam skid row , kix , cinderella , damn ya...
# 24397  bloody love -PRON- manager look at -PRON- the ...
# 9083        just go to lay in -PRON- bed and cry all day
# 51686  rt thank to i have learn way more than i ever ...
# 28152          donald putin 's butt buddy and a commie .
# 4630   -PRON- will never forget -PRON- . asian teen g...
# 56727  -PRON- get to understand that these bitch be c...
# 21568  look forward to -PRON- âmasterchef design by...
# 4787   ... friday ð wine ð · chill thankgod shit...
# 43113  -PRON- would hit a kardashian -PRON- throw mon...
# 14831  every time i hear the ice cream truck , -PRON-...
# 26068  -PRON- be so thankful that introduce -PRON- to...
# 39537  all i want be to represent da life o da colore...
# 15688  well , -PRON- blow up lap into the feature . t...
# 49129                 rt too many bitch not enough queen
#
#                                                 hashtags  \
# 3020                                 texas justicereform
# 30901                                          allahsoil
# 46268
# 52328
# 9255                                             lokiday
# 40462
# 22604                                    my gifts spoilt
# 17171                                  thankful positive
# 17869                                             friday
# 12416                                  thankful positive
# 40305
# 45417
# 43457
# 53964
# 842
# 362    lawofattraction resources healing altwaystohea...
# 5317
# 35190
# 21317                                       babiesmatter
# 56142
# 23618  girl me selfie redlips navy blueeyes smile eve...
# 51498                            signedtothestreets2 iGO
# 1810                   smile photography love mysonshine
# 36367
# 5474                                           emo yikez
# 46882                                   TVD Theoriginals
# 33226
# 38696
# 17044
# 54392
# 51460
# 40465
# 53493
# 10021
# 29971                                              trump
# 42005
# 24397                                    dreamteam cutie
# 9083
# 51686
# 28152
# 4630               asian teen gay boy love smile blessed
# 56727
# 21568                                            lustrum
# 4787                                   thankgod shitweek
# 43113
# 14831              songs trigger memories icecream truck
# 26068
# 39537
# 15688
# 49129
#
#                                             clean_tweet2
# 3020   texas the principal resign justicereform the p...
# 30901  allahsoil culture be like the horizon   always...
# 46268  rt that bitch who the shit in yo eye be not sh...
# 52328          rt yung nation riot   still bump that hoe
# 9255                 hi  PRON  friend lokiday for  PRON
# 40462                             coke and white bitch
# 22604   PRON  bihday friday   princess eden deserve g...
# 17171    i be thankful for happiness   thankful positive
# 17869  cheer  PRON  be friday ya ll happy hour be alw...
# 12416       i be thankful for clothe   thankful positive
# 40305  can not fuck with no bitch   just can not do  ...
# 45417  not that i plan on die soon   but  PRON  be to...
# 43457  if i do not unwrap a big booty hoe today  PRON...
# 53964  this bitch say use  PRON  titty as a punchin b...
# 842                    a number of  PRON  leader be come
# 362    good lawofattraction resource for heal altways...
# 5317                threat from terrorist be become real
# 35190                           PRON  be there bitch lol
# 21317  and yet the dem have no issue with aboion   cl...
# 56142  lol rt when  PRON  bae game amp an unknown hoe...
# 23618  red lips x navy top girl  PRON  selfie redlip ...
# 51498  rt so all  PRON  real fan who can wait and not...
# 1810   the simple thing in life make one happy smile ...
# 36367  oh yeah   and the annoying damn duck call  PRO...
# 5474                   figgity figgity fuck up emo yikez
# 46882  rt tvd and theoriginal be the show bad ass vam...
# 33226  when the nigga with the aux cord playin some t...
# 38696  lmao why would  PRON  respect  PRON  then  PRO...
# 17044  i listen to podcast and realize the should be ...
# 54392                                            w bitch
# 51460  rt bitches be out here eat pussy more than niggas
# 40465                                      come back hoe
# 53493  the bitch who just roll  PRON  eye at  PRON  b...
# 10021  racist assholes ban one of the sweetest and ki...
# 29971      the kind of  PRON  can expect in trump amrica
# 42005  i be jam skid row   kix   cinderella   damn ya...
# 24397  bloody love  PRON  manager look at  PRON  the ...
# 9083        just go to lay in  PRON  bed and cry all day
# 51686  rt thank to i have learn way more than i ever ...
# 28152          donald putin  s butt buddy and a commie
# 4630    PRON  will never forget  PRON    asian teen g...
# 56727   PRON  get to understand that these bitch be c...
# 21568  look forward to  PRON     masterchef design by...
# 4787       friday      wine       chill thankgod shit...
# 43113   PRON  would hit a kardashian  PRON  throw mon...
# 14831  every time i hear the ice cream truck    PRON ...
# 26068   PRON  be so thankful that introduce  PRON  to...
# 39537  all i want be to represent da life o da colore...
# 15688  well    PRON  blow up lap into the feature   t...
# 49129                 rt too many bitch not enough queen

# %%
pd.set_option("display.max_colwidth", -1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
#Most used words

stopwords = STOPWORDS.add('amp')

nonhate_words = ' '.join(tweets[tweets.label == 0].clean_tweet2.values)
hatred_words = ' '.join(tweets[tweets.label == 1].clean_tweet2.values)

plt.figure(figsize=(16, 8))

cloud1 = WordCloud(width=400, height=400, background_color='white', stopwords=stopwords).generate(nonhate_words)
plt.subplot(121)
plt.imshow(cloud1, interpolation="bilinear")
plt.axis("off")
plt.title('Non hate tweets', size=20)

cloud2 = WordCloud(width=400, height=400, background_color='white', stopwords=stopwords).generate(hatred_words)
plt.subplot(122)
plt.imshow(cloud2, interpolation="bilinear")
plt.axis("off")
plt.title('Hatred tweets', size=20)
plt.show()

# %%
#Most used hashtags

nonhate_hashtags = FreqDist(list(' '.join(tweets[tweets.label==0].hashtags.values).split())).most_common(10)
hatred_hashtags = FreqDist(list(' '.join(tweets[tweets.label==1].hashtags.values).split())).most_common(10)
plt.figure(figsize=(14, 6))
ax = plt.subplot(121)
pd.DataFrame(nonhate_hashtags, columns=['hashtag', 'Count']).set_index('hashtag').plot.barh(ax=ax, fontsize=12)
plt.xlabel('# occurrences')
plt.title('Hashtags in nonhate tweets', size=13)
ax = plt.subplot(122)
pd.DataFrame(hatred_hashtags, columns=['hashtag', 'Count']).set_index('hashtag').plot.barh(ax=ax, fontsize=12)
plt.xlabel('# occurrences')
plt.ylabel('')
plt.title('Hashtags in hatred tweets', size=13)
plt.show()

# %%
#Splitting the data in 80% train and 20% test

X_train, X_test, Y_train, Y_test = train_test_split(list(tweets.clean_tweet2), list(tweets.label),test_size=0.2, random_state=42)
